# %% [markdown]
# # CAU Computer Vision - Project 1

# %% [markdown]
# ## import library

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
patch_size = 10

# %%
def cv2_imshow(name: str, src):
    cv2.namedWindow(name, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(name, 800, 800)
    cv2.moveWindow(name, 500, 100)

    cv2.imshow(name, src)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# ## Click and get patch for 1st.jpg
# ### Get coordinate

# %%
coord1 = []

def getCoord_1(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        coord1.append((y,x))
        print(x, y)

# %%
image1_original = cv2.imread("1st.jpg")

cv2.namedWindow("1st", cv2.WINDOW_NORMAL)
cv2.resizeWindow("1st", 800, 800)
cv2.moveWindow("1st", 500, 100)
cv2.setMouseCallback("1st", getCoord_1)

cv2.imshow("1st", image1_original)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 144 1905
# 1727 3609
# 2982 2419
# 1372 746

# %% [markdown]
# ### Make blurred, grayscaled images

# %%
image1_blur = cv2.GaussianBlur(image1_original, (0, 0), 1)
image1_gray = cv2.cvtColor(image1_original, cv2.COLOR_BGR2GRAY)
image1_gb = cv2.GaussianBlur(image1_gray, (0,0), 1)

# cv2_imshow("image1_original", image1_original)
# cv2_imshow("image1_blur", image1_blur)
# cv2_imshow("image1_gray", image1_gray)
# cv2_imshow("image1_gb", image1_gb)

# %% [markdown]
# ### Make patch for each clicked points

# %%
patch1_original = [image1_original[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]
patch1_blur = [image1_blur[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]
patch1_gray = [image1_gray[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]
patch1_gb = [image1_gb[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]

# %% [markdown]
# ### Show patches of 1st.jpg

# %%
# for i in range(len(patch1_original)):
#     wname = "1st_" + str(i)
#     cv2_imshow(wname, patch1_original[i])

# for i in range(len(patch1_blur)):
#     wname = "1st_" + str(i)
#     cv2_imshow(wname, patch1_blur[i])

# for i in range(len(patch1_gray)):
#     wname = "1st_" + str(i)
#     cv2_imshow(wname, patch1_gray[i])

# for i in range(len(patch1_gb)):
#     wname = "1st_" + str(i)
#     cv2_imshow(wname, patch1_gb[i])

# %% [markdown]
# ## Click and get patch for 2st.jpg
# ### Get coordinate

# %%
coord2 = []

def getCoord_2(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        coord2.append((y,x))
        print(x, y)

# %%
image2_original = cv2.imread("2nd.jpg")

cv2.namedWindow("2nd", cv2.WINDOW_NORMAL)
cv2.resizeWindow("2nd", 800, 800)
cv2.moveWindow("2nd", 500, 100)
cv2.setMouseCallback("2nd", getCoord_2)

cv2.imshow("2nd", image2_original)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 786 1109
# 665 3543
# 2548 3634
# 2563 1119

# %% [markdown]
# ### Make blurred, grayscaled images

# %%
image2_blur = cv2.GaussianBlur(image2_original, (0, 0), 1)
image2_gray = cv2.cvtColor(image2_original, cv2.COLOR_BGR2GRAY)
image2_gb = cv2.GaussianBlur(image2_gray, (0,0), 1)

# cv2_imshow("image2_original", image2_original)
# cv2_imshow("image2_blur", image2_blur)
# cv2_imshow("image2_gray", image2_gray)
# cv2_imshow("image2_gb", image2_gb)

# %% [markdown]
# ### Make patch for each clicked points

# %%
patch2_original = [image2_original[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]
patch2_blur = [image2_blur[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]
patch2_gray = [image2_gray[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]
patch2_gb = [image2_gb[coord1[i][0]-patch_size:coord1[i][0]+patch_size+1, coord1[i][1]-patch_size:coord1[i][1]+patch_size+1] for i in range(len(coord1))]

# %% [markdown]
# ### Show patches of 2nd.jpg

# %%
# for i in range(len(patch2_original)):
#     wname = "2nd_" + str(i)
#     cv2_imshow(wname, patch2_original[i])

# for i in range(len(patch2_blur)):
#     wname = "2nd_" + str(i)
#     cv2_imshow(wname, patch2_blur[i])

# for i in range(len(patch2_gray)):
#     wname = "2nd_" + str(i)
#     cv2_imshow(wname, patch2_gray[i])

# for i in range(len(patch2_gb)):
#     wname = "2nd_" + str(i)
#     cv2_imshow(wname, patch2_gb[i])

# %% [markdown]
# ## Histograms

# %%
hist_bin_gradient = 350/35
hist_bin_color = 256/10

# %%
def norm_gradient(src):
    
    x_forward = np.concatenate([src[:, 1:], src[:, -1:]], axis = 1)
    x_backward = np.concatenate([src[:, :1], src[:, :-1]], axis = 1)
    Dx = np.subtract(x_forward, x_backward)/2

    y_forward = np.concatenate([src[1:, :], src[-1:, :]])
    y_backward = np.concatenate([src[:1, :], src[:-1, :]])
    Dy = np.subtract(y_forward, y_backward)/2

    norm_gradient = np.sqrt(np.add(np.square(Dx), np.square(Dy)))
    norm_gradient = np.uint8(np.around(norm_gradient))
    
    return norm_gradient

# %%
def gradient_histogram_color(src_list):
    hist_list = []

    for i in range(len(src_list)):
        print(f"- {i+1}th -")
        temp = []

        channels = cv2.split(src_list[i])
        colors = ['b', 'g', 'r']

        for ch, color in zip(channels, colors):
            src = cv2.Laplacian(ch, -1)
            src = src - np.min(src)
            src = np.uint8((src / np.max(src)) * 360)
            hist = cv2.calcHist([src], [0], None, [int(350/hist_bin_gradient)], [10,360])
            hist = cv2.normalize(hist, hist, 0, 1, cv2.NORM_MINMAX)
            temp.append(hist)
            plt.plot(hist, color=color)
        plt.show()
        hist_list.append(temp)

    return hist_list

# %%
def color_histogram_color(src_list):
    hist_list = []

    for i in range(len(src_list)):
        print(f"- {i+1}th -")
        temp = []

        channels = cv2.split(src_list[i])
        colors = ['b', 'g', 'r']

        for ch, color in zip(channels, colors):
            src = ch - np.min(ch)
            src = np.uint8((src / np.max(src)) * 255)
            hist = cv2.calcHist([src], [0], None, [int(256/hist_bin_color)], [0,255])
            hist = cv2.normalize(hist, hist, 0, 1, cv2.NORM_MINMAX)
            temp.append(hist)
            plt.plot(hist, color=color)
        plt.show()
        hist_list.append(temp)

    return hist_list

# %%
def gradient_histogram_gray(src_list):
    hist_list = []

    for i in range(len(src_list)):
        print(f"- {i+1}th -")
        src = cv2.Laplacian(src_list[i], -1)
        src = src - np.min(src)
        src = np.uint8((src / np.max(src)) * 360)
        hist = cv2.calcHist([src], [0], None, [int(350/hist_bin_gradient)], [10, 300])
        hist = cv2.normalize(hist, hist, 0, 1, cv2.NORM_MINMAX)
        hist_list.append(hist)
        plt.plot(hist)
        plt.show()

    return hist_list

# %%
def color_histogram_gray(src_list):
    hist_list = []

    for i in range(len(src_list)):
        print(f"- {i+1}th -")
        src = src_list[i] - np.min(src_list[i])
        src = np.uint8((src / np.max(src)) * 255)
        hist = cv2.calcHist([src], [0], None, [int(256/hist_bin_color)], [0,255])
        hist = cv2.normalize(hist, hist, 0, 1, cv2.NORM_MINMAX)
        hist_list.append(hist)
        plt.plot(hist)
        plt.show()

    return hist_list

# %% [markdown]
# ### 1) Color images
# #### (1) None_blur
# ##### a. Gradient Histogram

# %%
print("!!!!!  Color - NoneBlur - Gradient Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_CNG = gradient_histogram_color(patch1_original)

print("*** 2nd.jpg ****")
hl2_CNG = gradient_histogram_color(patch2_original)
# Out:
# !!!!!  Color - NoneBlur - Gradient Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# ##### b. Color Histogram

# %%
print("!!!!!  Color - NoneBlur - Color Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_CNC = color_histogram_color(patch1_original)

print("*** 2nd.jpg ****")
hl2_CNC = color_histogram_color(patch2_original)
# Out:
# !!!!!  Color - NoneBlur - Color Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# #### (2) Blur
# ##### a. Gradient Histogram

# %%
print("!!!!!  Color - Blur - Gradient Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_CBG = gradient_histogram_color(patch1_blur)

print("*** 2nd.jpg ****")
hl2_CBG = gradient_histogram_color(patch2_blur)
# Out:
# !!!!!  Color - Blur - Gradient Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# ##### b. Color Histogram

# %%
print("!!!!!  Color - Blur - Color Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_CBC = color_histogram_color(patch1_blur)

print("*** 2nd.jpg ****")
hl2_CBC = color_histogram_color(patch2_blur)
# Out:
# !!!!!  Color - Blur - Color Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# ### 2) Gray images
# #### (1) None_blur
# ##### a. Gradient Histogram

# %%
print("!!!!!  Gray - NoneBlur - Gradient Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_GNG = gradient_histogram_gray(patch1_gray)

print("*** 2nd.jpg ****")
hl2_GNG = gradient_histogram_gray(patch2_gray)
# Out:
# !!!!!  Gray - NoneBlur - Gradient Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# ##### b. Color Histogram(brightness)

# %%
print("!!!!!  Gray - NoneBlur - Color Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_GNC = gradient_histogram_color(patch1_gray)

print("*** 2nd.jpg ****")
hl2_GNC = gradient_histogram_color(patch2_gray)
# Out:
# !!!!!  Gray - NoneBlur - Color Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# #### (2) Blur
# ##### a. Gradient Histogram

# %%
print("!!!!!  Gray - Blur - Gradient Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_GBG = gradient_histogram_gray(patch1_gb)

print("*** 2nd.jpg ****")
hl2_GBG = gradient_histogram_gray(patch2_gb)
# Out:
# !!!!!  Gray - Blur - Gradient Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# ##### b. Color Histogram

# %%
print("!!!!!  Gray - Blur - Color Histogram  !!!!!")

print("*** 1st.jpg ****")
hl1_GBC = color_histogram_gray(patch1_gb)

print("*** 2nd.jpg ****")
hl2_GBC = color_histogram_gray(patch2_gb)
# Out:
# !!!!!  Gray - Blur - Color Histogram  !!!!!
# *** 1st.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -
# *** 2nd.jpg ****
# - 1th -
# - 2th -
# - 3th -
# - 4th -

# %% [markdown]
# ## Matching
# ### Calculate similarity

# %%
def matching_histcomp(hist1, hist2):
    histcomp = []

    for i in range(4):
        q = np.array(hist1[i])
        temp = []
        for j in range(4):
            t = np.array(hist2[j])
            ret = cv2.compareHist(q, t, cv2.HISTCMP_CORREL)
            temp.append(ret)
        histcomp.append(temp)

    res = []
    for h1 in range(4):
        max_val = max(histcomp[h1])
        index = None
        for h2 in range(4):
            if max_val == histcomp[h1][h2]:
                index = h2
        res.append(index)
    return (histcomp, res)

# %%
def matching_color_mse(hist1, hist2):
    mse = []
    for h1 in range(4):
        h1_mse = []
        for h2 in range(4):
            h1_mse.append(np.sum(np.square(np.subtract(hist1[h1], hist2[h2])).mean()))
        mse.append(h1_mse)

    res = []
    for h1 in range(4):
        min_val = 99999999999
        index = None
        for h2 in range(4):
            if mse[h1][h2] < min_val:
                min_val = mse[h1][h2]
                index = h2
        res.append(index)
            
    return (mse, res)

# %%
def matching_gray_mse(hist1, hist2):
    mse = []
    for h1 in range(4):
        h1_mse = []
        for h2 in range(4):
            h1_mse.append(np.square(np.subtract(hist1[h1], hist2[h2])).mean())
        mse.append(h1_mse)

    res = []
    for h1 in range(4):
        min_val = 99999999999
        index = None
        for h2 in range(4):
            if mse[h1][h2] < min_val:
                min_val = mse[h1][h2]
                index = h2
        res.append(index)
            
    return (mse, res)

# %% [markdown]
# ### Draw box and line

# %%
rec_size = 50

def draw_rectangle(src, coord):
    colors = [(0,0,255), (255,0,0), (0,255,0), (255,255,255)]
    t = src.copy()
    for i in range(len(coord)):
        t = cv2.rectangle(t, [coord[i][1]-rec_size, coord[i][0]-rec_size], [coord[i][1]+rec_size, coord[i][0]+rec_size], colors[i], 10)
    return t

rectangled = np.concatenate((draw_rectangle(image1_original, coord1), draw_rectangle(image2_original, coord2)), axis=1)

# %%
line_size = 10

def draw_line(src, coord1, coord2, match):
    t = src.copy()
    for i in range(len(match)):
        t = cv2.line(t, (coord1[i][1], coord1[i][0]), (coord2[match[i]][1] + image1_original.shape[1], coord2[match[i]][0]), color=(0,0,0), thickness=line_size)
    return t

# %% [markdown]
# Color image: NoneBlur, Gradient histogram

# %%
match = matching_histcomp(hl1_CNG, hl2_CNG)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Color_NoneBlur_Gradient.jpg", lined)
print(match)
# Out:
# ([[0.7895145439844691, 0.9013683949794277, 0.8466591439646536, 0.6562544161892505], [0.7295047705145643, 0.9248729460613375, 0.9255370055082659, 0.7334362691648634], [0.7858907249308267, 0.9233267725243964, 0.8686582503682313, 0.6958452019041067], [0.7948898981815522, 0.9157832927770639, 0.9152460214164005, 0.7193601154371378]], [1, 2, 1, 1])

# %% [markdown]
# Color image: NonBlur, Color histogram

# %%
match = matching_histcomp(hl1_CNC, hl2_CNC)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Color_NoneBlur_Color.jpg", lined)
print(match)
# Out:
# ([[0.08625954532950608, 0.5975688918696458, -0.14900369491957635, 0.03963665913032257], [-0.1889041736421433, 0.10807011417072182, -0.24299003963374588, -0.1542527783272563], [0.37749825650594043, 0.05619655812742888, 0.2822088455437069, 0.12196339624535847], [0.5070747458967689, 0.024296621824131816, 0.8229256987959676, 0.6889893212163456]], [1, 1, 0, 2])

# %% [markdown]
# Color image: Blur, Gradient histogram

# %%
match = matching_histcomp(hl1_CBG, hl2_CBG)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Color_Blur_Gradient.jpg", lined)
print(match)
# Out:
# ([[0.22268542523461698, 0.8593596612584327, 0.258715111939865, 0.26474623605764713], [-0.10847660159508057, 0.6705858241441842, 0.45778690595119675, 0.008841928405063829], [0.14418016931595143, 0.9001361448729825, 0.4210676607737675, 0.1684241415878051], [0.24158499475318337, 0.8797035931740996, 0.3818974489326594, 0.15094729077710706]], [1, 1, 1, 1])

# %% [markdown]
# Color image: Blur, Color histogram

# %%
match = matching_histcomp(hl1_CBC, hl2_CBC)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Color_Blur_Color.jpg", lined)
print(match)
# Out:
# ([[-0.3359782347377143, 0.5604614094453324, -0.24726481129462494, -0.23608464067226875], [-0.3815701471815951, 0.29116556840892566, -0.2132160193296991, -0.21462819609398992], [0.11789073858129347, -0.22781512554491262, 0.08559498921098123, 0.024375229561231972], [0.5846478051574139, -0.280945408592653, 0.4861594555293159, 0.5432461010919364]], [1, 1, 0, 0])

# %% [markdown]
# Gray image: NoneBlur, Gradient histogram

# %%
match = matching_histcomp(hl1_GNG, hl2_GNG)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Gray_NoneBlur_Gradient.jpg", lined)
print(match)
# Out:
# ([[0.6796774140720964, 0.8861746318482834, 0.8380072075691067, 0.5719878569628524], [0.7035346499187136, 0.8927562644003798, 0.7005235824899992, 0.43281124947278143], [0.7669238528568659, 0.8356734980208013, 0.7754291769113553, 0.7346574168657728], [0.6166222216815672, 0.8850466665500326, 0.7929623862365246, 0.4988656384860768]], [1, 1, 1, 1])

# %% [markdown]
# Gray image: NoneBlur, Color histogram

# %%
match = matching_histcomp(hl1_GNC, hl2_GNC)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Gray_NoneBlur_Color.jpg", lined)
print(match)
# Out:
# ([[0.8750537732889377, 0.9149078192522523, 0.7982532082167318, 0.5856450084862128], [0.8013199084588694, 0.9425202830146132, 0.8930110456680149, 0.6844166775591609], [0.8137427107746741, 0.9599939393520616, 0.9233903641890239, 0.7152887807508139], [0.8341644777655647, 0.9287362866284828, 0.9339206959815364, 0.6219148495927784]], [1, 1, 1, 2])

# %% [markdown]
# Gray image: Blur, Gradient histogram

# %%
match = matching_histcomp(hl1_GBG, hl2_GBG)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Gray_Blur_Gradient.jpg", lined)
print(match)
# Out:
# ([[-0.07569723554685841, 0.7942550090540905, 0.24645929769844793, -0.07395765149273797], [0.14879071663286358, 0.6727747562438693, 0.5483237130453636, 0.1366031139860315], [0.0951123351432384, 0.9056426215148936, 0.19602408645393704, 0.16607226902141148], [0.11631049850025238, 0.8212773089353234, 0.331818415401638, 0.032199527489006674]], [1, 1, 1, 1])

# %% [markdown]
# Gray image: Blur, Color histogram

# %%
match = matching_histcomp(hl1_GBC, hl2_GBC)
lined = draw_line(rectangled, coord1, coord2, match[1])
cv2.imwrite("res/Gray_Blur_Color.jpg", lined)
print(match)
# Out:
# ([[-0.32172386902277295, 0.48624107106975556, -0.1969126221741119, -0.20253417982530827], [-0.5375438129789435, 0.17933128495523576, -0.2021671175016153, -0.04431316705160181], [0.6108952131295978, -0.3914649232385815, 0.340749932727296, -0.23789370668606208], [0.5177786004438247, -0.41722048132472345, 0.6988784322028885, 0.3652222284868027]], [1, 1, 0, 2])
